# %% [markdown]
# <a href="https://colab.research.google.com/github/shigonoke/3_4/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Семинар10 Построение графиков
# Задача №63. Решение в группах 
# 1.Изобразите отношение households к population с помощью точечного графика 
# 2.Визуализировать longitude по отношения к median_house_value, используя линейный график 
# 3.Представить гистограмму по housing_median_age 
# 4.Изобразить гистограмму по median_house_value с оттенком housing_median_age
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv', sep=',')

# %%
df.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0

# %%
#  1.Изобразите отношение households к population с помощью точечного графика
ax = sns.scatterplot(data=df, x='population', y='households')

# %%
# 2.Визуализировать longitude по отношения к median_house_value, используя линейный график
sns.relplot(data=df, x="longitude", y="median_house_value", kind="line", aspect=3)

# %%
# 3.Представить гистограмму по housing_median_age
sns.histplot(data=df, x='housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
# 4.Изобразить гистограмму по median_house_value с оттенком housing_median_age
ax = sns.histplot(data=df, x='median_house_value', hue='housing_median_age')

# %%
ax = sns.histplot(data=df, x='median_house_value', y='housing_median_age')

# %%
# Задача №65. Решение в группах Написать EDA для датасета про пингвинов Необходимо: 
# Использовать 2-3 точечных графика 
# ●Применить доп измерение в точечных графиках, используя аргументы hue, size, stile
#  ●Использовать PairGrid с типом графика на ваш выбор 
#  ●Изобразить Heatmap 
#  ●Использовать 2-3 гистограммы 
#  Чтобы подключить датасет с пингвинами, воспользуйтесь данным скриптом:
penguins = sns.load_dataset("penguins") 
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.shape
# Out:
# (344, 7)

# %%
penguins.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
penguins.dropna(inplace=True) 
# убирает пропуски

# %%
# Использовать 2-3 точечных графика
sns.scatterplot(data=penguins, x='body_mass_g', y='bill_depth_mm')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins, x='body_mass_g', y='flipper_length_mm')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
# ●Применить доп измерение в точечных графиках, используя аргументы hue, size, stile
sns.scatterplot(data=penguins, x='body_mass_g', y='bill_depth_mm', hue='species')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins, x='body_mass_g', y='flipper_length_mm', hue='island')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.scatterplot(data=penguins, x='body_mass_g', y='flipper_length_mm', hue='sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
#  ●Использовать PairGrid с типом графика на ваш выбор
lst = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'sex']
# выделить те колонки по кот-ым мы хотим получить графики
g = sns.PairGrid(penguins[lst])
# PairGrid переберет все пары столбцов и выведет их в графике
g.map_lower(sns.histplot)
# lower какие графики использовать внизу
g.map_upper(sns.scatterplot)
# вывести

# %%
#  ●Изобразить Heatmap 
penguins.corr()
# Out:
# <ipython-input-31-2939429c3bb2>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   penguins.corr()
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
#
#                    body_mass_g
# bill_length_mm        0.589451
# bill_depth_mm        -0.472016
# flipper_length_mm     0.872979
# body_mass_g           1.000000

# %%
sns. heatmap(data=penguins.corr(), vmin=-1, vmax=1)
# Out:
# <ipython-input-33-5508d91db284>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns. heatmap(data=penguins.corr(), vmin=-1, vmax=1)
# <Axes: >

# %%
# ● Использовать 2-3 гистограммы
sns.histplot(data=penguins, x='island', hue='species')
# Out:
# <Axes: xlabel='island', ylabel='Count'>

# %%
# Задача №67. Решение в группах 
# 1.Создать новый столбец в таблице с пингвинами, который будет отвечать  за показатель длины клюва пингвина.
#  high - длинный(от 42) middle - средний(от 35 до 42) low - маленький(до 35) 
#  Чтобы подключить датасет с пингвинами, воспользуйтесь данным скриптом: 
#  penguins = sns.load_dataset("penguins") 
#  penguins.head()
penguins['bill_length_mm'] > 42
# Out:
# 0      False
# 1      False
# 2      False
# 4      False
# 5      False
#        ...
# 338     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: bill_length_mm, Length: 333, dtype: bool

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.loc[penguins['bill_length_mm'] >= 42, 'height_group'] = 'high'

# %%
# middle - средний(от 35 до 42)
penguins.loc[(penguins['bill_length_mm'] >=35) & (penguins['bill_length_mm'] < 42), 'height_group'] = 'middle'

# %%
# low - маленький(до 35)
penguins.loc[penguins['bill_length_mm'] < 35, 'height_group'] = 'low'

# %%
penguins.height_group.unique()
# какие значения встречаются в колонке
# Out:
# array(['middle', nan, 'low', 'high'], dtype=object)

# %%
# Задача №69. Решение в группах 
# 1.Изобразить гистограмму по flipper_length_mm с оттенком height_group. Сделать анализ
sns.histplot(data=penguins, x='flipper_length_mm', hue='height_group')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>
